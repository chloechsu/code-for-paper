# %%
import os
import sys

import seaborn as sns
import numpy as np
import matplotlib
matplotlib.use('qt5agg')
import matplotlib.pyplot as plt
import torch
import pandas as pd
sns.set(style='whitegrid', rc={
    'figure.figsize':(12,8),
    'legend.fontsize': 'large',
    'legend.title_fontsize': 'large',
    'axes.labelsize': 'large',
    'axes.titlesize':'large',
    'xtick.labelsize':'large',
    'ytick.labelsize':'large',
    'font.family': 'sans-serif',
    'font.sans-serif': 'Lucida Grande'
})

from simulated_utils import compare
from simulated_utils import TwoActionEnv

# %%
# %matplotlib inline

# %%
 def plot_results(data):
    fig, axes = plt.subplots(2, 2, figsize=(16, 10), sharex=True)
    sns.lineplot(data=data, x='iter', y='mean_reward', hue='method', ax=axes[0][0], n_boot=100)
    sns.lineplot(data=data, x='iter', y='loss', hue='method', ax=axes[0][1], n_boot=100)
    sns.lineplot(data=data, x='iter', y='pd_param_0_mean', hue='method', ax=axes[1][0], n_boot=100)
    sns.lineplot(data=data, x='iter', y='pd_param_1_mean', hue='method', ax=axes[1][1], n_boot=100)

    handles, labels = axes.flatten()[0].get_legend_handles_labels()
    for ax in axes.flatten():
        ax.get_legend().remove()
    fig.legend(handles[1:], labels[1:], loc='upper center', title='method', ncol=4)
    plt.show()

# %%
env = TwoActionEnv(noise_std=1e-3)
data = compare('discrete', env=env, action_dim=2, n_steps=40, repeats=10, lr=1e-1,
               batch_size=2, num_minibatches=1, kl_penalty_coeff=2., clip_eps=0.5, ppo_epochs=1)

# %%
plot_results(data)

# %%
env = TwoActionEnv(noise_std=1e-3)
data = compare('discrete', env=env, action_dim=2, n_steps=40, repeats=100, lr=1e-1,
               batch_size=2, num_minibatches=1, kl_penalty_coeff=2., clip_eps=0.5, ppo_epochs=10)
# Out:
# //anaconda3/envs/ppo/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
plot_results(data)

# %%
env = TwoActionEnv(noise_std=1e-3)
data = compare('discrete', env=env, action_dim=2, n_steps=40, repeats=5, lr=1e-1,
               batch_size=4, num_minibatches=1, kl_penalty_coeff=2., clip_eps=0.5, ppo_epochs=50)

# %%
plot_results(data)

# %%
env = TwoActionEnv(noise_std=1e-3)
data = compare('discrete', env=env, action_dim=2, n_steps=10, repeats=1, lr=3e-4,
               batch_size=256, num_minibatches=32, kl_penalty_coeff=3., clip_eps=0.2, ppo_epochs=10)

# %%
plot_results(data)

# %%
env = TwoActionEnv(noise_std=1e-3)
data = compare('discrete', env=env, action_dim=2, n_steps=10, repeats=1, lr=3e-4,
               batch_size=256, num_minibatches=32, kl_penalty_coeff=3., clip_eps=0.2, ppo_epochs=50)
plot_results(data)
# Out:
# //anaconda3/envs/ppo/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
env = TwoActionEnv(noise_std=1e-3)
data = compare('discrete', env=env, action_dim=2, n_steps=10, repeats=1, lr=3e-4,
               batch_size=256, num_minibatches=32, kl_penalty_coeff=3., clip_eps=0.2, ppo_epochs=100)
plot_results(data)
# Out:
# //anaconda3/envs/ppo/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
env = TwoActionEnv(noise_std=1e-3)
data = compare('discrete', env=env, action_dim=2, n_steps=5, repeats=1, lr=3e-4,
               batch_size=256, num_minibatches=32, kl_penalty_coeff=3., clip_eps=0.2, ppo_epochs=200)
plot_results(data)

# %%
env = TwoActionEnv(noise_std=1e-3)
data = compare('discrete', env=env, action_dim=2, n_steps=100, repeats=5, lr=3e-4,
               batch_size=4, num_minibatches=1, kl_penalty_coeff=2., clip_eps=0.5, ppo_epochs=50)
# Out:
# //anaconda3/envs/ppo/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
plot_results(data)
